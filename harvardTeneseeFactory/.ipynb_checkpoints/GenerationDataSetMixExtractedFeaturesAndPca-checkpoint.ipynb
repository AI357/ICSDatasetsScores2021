# %%
from sklearn import metrics
from sklearn import preprocessing
from sklearn import model_selection
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, roc_auc_score,auc, accuracy_score
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.model_selection import train_test_split
from scipy.stats import entropy
from statsmodels.tsa import stattools
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose
from pandas.plotting import autocorrelation_plot
import scipy




ALLtrain = pd.read_csv("ALLtrain")
#ALLtest = pd.read_csv("ALLtest")

ALLtrain = ALLtrain.drop(['Unnamed: 0'],axis=1)
#ALLtest = ALLtest.drop(['Unnamed: 0'],axis=1)

# %%
# dans ce notebook, on procède à plusieurs opérations pour avoir seulement 3 échantilions sur 500 lors que chaque simulation
# cela dans le but d'avoir la même fréquence d'échantillonnage que le dataset statistiques afin de les utiliser ensemble

# %%
featuresonderepartition = pd.read_csv('featuresonderepartition')

# %%
ALLtrain.head()
# Out:
#    faultNumber  simulationRun  sample   xmeas_1   xmeas_2   xmeas_3   xmeas_4  \
# 0            0              1       1  0.475064  0.546864  0.553922  0.342491
# 1            0              1       2  0.477701  0.497640  0.633506  0.599260
# 2            0              1       3  0.475064  0.500674  0.406286  0.620658
# 3            0              1       4  0.472799  0.504046  0.505190  0.666887
# 4            0              1       5  0.637231  0.563722  0.461649  0.482631
#
#     xmeas_5   xmeas_6   xmeas_7    ...        xmv_2     xmv_3     xmv_4  \
# 0  0.502410  0.541063  0.479042    ...     0.409893  0.480777  0.628029
# 1  0.412426  0.634461  0.489521    ...     0.327865  0.478160  0.314635
# 2  0.494912  0.362856  0.507485    ...     0.562267  0.481118  0.506964
# 3  0.432244  0.359098  0.522455    ...     0.460104  0.483355  0.371589
# 4  0.502410  0.674181  0.491018    ...     0.388516  0.637749  0.453730
#
# ...

# %%
print("init")
Ctraining = pd.DataFrame(columns = ALLtrain.columns)
arr2 = []
indiceMin = 165
ecart = 165
x = np.arange(ecart).reshape(-1,1)

SousfenetreEcart = int(ecart/5)
columns = ALLtrain.drop(['faultNumber','simulationRun','sample'],axis=1).columns
print("starting")
for case in range(0,21):
    for simulation in range(1,500):
        if simulation > 99 and case != 0:
            break
        #print('simu : ',simulation)
        

        for id in range(0,501,ecart):

            if id % ecart == 0 and id!=0:    
                
                
                dico = ALLtrain[ALLtrain['faultNumber'] == case ][ALLtrain['simulationRun'] == simulation][ALLtrain['sample'] == id]
                #print(dico)
                
                Ctraining = Ctraining.append(dico,ignore_index=True )
# Out:
# init
# C:\ProgramData\Anaconda3\envs\IA 1\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\ProgramData\Anaconda3\envs\IA 1\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\ProgramData\Anaconda3\envs\IA 1\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\ProgramData\Anaconda3\envs\IA 1\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\ProgramData\Anaconda3\envs\IA 1\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\ProgramData\Anaconda3\envs\IA 1\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %%
Ctraining.head()
# Out:
#   faultNumber simulationRun sample   xmeas_1   xmeas_2   xmeas_3   xmeas_4  \
# 0           0             1    165  0.479632  0.637559  0.367359  0.365870
# 1           0             1    330  0.246611  0.692178  0.455594  0.625017
# 2           0             1    495  0.452189  0.433581  0.450692  0.548805
# 3           0             2    165  0.486019  0.398517  0.611592  0.426232
# 4           0             2    330  0.562442  0.552596  0.455594  0.264958
#
#     xmeas_5   xmeas_6   xmeas_7    ...        xmv_2     xmv_3     xmv_4  \
# 0  0.525442  0.572732  0.332335    ...     0.519264  0.499128  0.549227
# 1  0.463846  0.509930  0.624251    ...     0.670892  0.249716  0.524137
# 2  0.535619  0.324745  0.483533    ...     0.539647  0.449799  0.385804
# 3  0.475094  0.699410  0.552395    ...     0.414865  0.492113  0.380939
# 4  0.437065  0.432636  0.356287    ...     0.529953  0.555623  0.493703
#
#       xmv_5     xmv_6     xmv_7     xmv_8     xmv_9    xmv_10    xmv_11
# ...

# %%
Ctraining.columns
# Out:
# Index(['faultNumber', 'simulationRun', 'sample', 'xmeas_1', 'xmeas_2',
#        'xmeas_3', 'xmeas_4', 'xmeas_5', 'xmeas_6', 'xmeas_7', 'xmeas_8',
#        'xmeas_9', 'xmeas_10', 'xmeas_11', 'xmeas_12', 'xmeas_13', 'xmeas_14',
#        'xmeas_15', 'xmeas_16', 'xmeas_17', 'xmeas_18', 'xmeas_19', 'xmeas_20',
#        'xmeas_21', 'xmeas_22', 'xmeas_23', 'xmeas_24', 'xmeas_25', 'xmeas_26',
#        'xmeas_27', 'xmeas_28', 'xmeas_29', 'xmeas_30', 'xmeas_31', 'xmeas_32',
#        'xmeas_33', 'xmeas_34', 'xmeas_35', 'xmeas_36', 'xmeas_37', 'xmeas_38',
#        'xmeas_39', 'xmeas_40', 'xmeas_41', 'xmv_1', 'xmv_2', 'xmv_3', 'xmv_4',
#        'xmv_5', 'xmv_6', 'xmv_7', 'xmv_8', 'xmv_9', 'xmv_10', 'xmv_11'],
#       dtype='object')

# %%
Ctraining.to_csv('DF3samplesPerSimu')

# %%
#CtrainingPca
